# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %% [markdown]
# # variables

# %%
b1=65
b1
# Out:
# 65

# %% [markdown]
# # To store data

# %%
abc=92
abc
# Out:
# 92

# %% [markdown]
# # comments

# %% [markdown]
# #### single line comment - we use hash tag
# #### multi line comment - we use  """  """

# %%
x=5
y=10
z=x+y    #code for adding two numbers or ctrl + /
print(z)
# Out:
# 15

# %%
x=5
y=10
z=x+y
""" hi
hello
how are you"""
print(z)
# Out:
# 15

# %%
##Data Types
####4 types of data
####1)integer
####2)float
####3)String
####4)boolean
####5)complex

# %%
a1 = 35
type(a1)
# Out:
# int

# %%
type(45.5)
# Out:
# float

# %%
type("hi")
# Out:
# str

# %%
type("TRUE")
# Out:
# str

# %%
type(True)
# Out:
# bool
