# %%
a1=33
str(a1)
# Out:
# '33'

# %% [markdown]
# ### Data Type Casting

# %% [markdown]
# ### int - float
# ###int - string

# %% [markdown]
# ### float - int
# ###float - srin

# %% [markdown]
# ### String - int(int)
# ###String - float(int)

# %% [markdown]
# ### String - float (float)

# %% [markdown]
# ### Strings

# %%
a1 = 'hello everyone'
a1
# Out:
# 'hello everyone'

# %%
len(a1)
# Out:
# 14

# %% [markdown]
# ### Indexing

# %%
a1
# Out:
# 'hello everyone'

# %%
a1[4]
# Out:
# 'o'

# %%
a1[9]
# Out:
# 'r'

# %% [markdown]
# ### slicing

# %% [markdown]
# ### a1[start :End:SS]

# %%
a1[0:5]
# Out:
# 'hello'

# %%
a1[0:5:1]
# Out:
# 'hello'

# %%
a1[0:5:2]
# Out:
# 'hlo'

# %%
a1[0:5:3]
# Out:
# 'hl'

# %%
a1[6:14:2]
# Out:
# 'eeyn'
