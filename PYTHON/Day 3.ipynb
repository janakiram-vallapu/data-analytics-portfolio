# %%
a1 = 'hello everyone'
a1
# Out:
# 'hello everyone'

# %%
a1.upper()
# Out:
# 'HELLO EVERYONE'

# %%
Strings are immutable

# %%
b1=a1.upper()
b1
# Out:
# 'HELLO EVERYONE'

# %%
a1.lower()
# Out:
# 'hello everyone'

# %%
a1.capitalize()
# Out:
# 'Hello everyone'

# %%
a1.count('o')
# Out:
# 2

# %%
a1.count('e')
# Out:
# 4

# %%
a1.index('y')
# Out:
# 10

# %%
a1.index('e')
# Out:
# 1

# %%
a2 = 'Hello Everyone'
a2
# Out:
# 'Hello Everyone'

# %%
a2.replace('Hello','hi')
# Out:
# 'hi Everyone'

# %%
a3 = ' Hello Everyone '
a3
# Out:
# ' Hello Everyone '

# %%
a3.strip(' ')
# Out:
# 'Hello Everyone'

# %%
a3
# Out:
# ' Hello Everyone '

# %%
a3.strip()
# Out:
# 'Hello Everyone'

# %%
a4 = '***Hello**everyone****'
a4
# Out:
# '***Hello**everyone****'

# %%
a4.strip('*')
# Out:
# 'Hello**everyone'

# %%
a4.lstrip('*')
# Out:
# 'Hello**everyone****'

# %%
a4.rstrip('*')
# Out:
# '***Hello**everyone'

# %%
a5 = 'apple banana orange kiwi'
a5
# Out:
# 'apple banana orange kiwi'

# %%
a5.split(' ')
# Out:
# ['apple', 'banana', 'orange', 'kiwi']

# %%
a5.split()
# Out:
# ['apple', 'banana', 'orange', 'kiwi']

# %% [markdown]
# ### string concatination

# %%
c1 = 'data'
c2 = 'science'
c1+c2
# Out:
# 'datascience'

# %%
c1+' '+c2
# Out:
# 'data science'

# %%
1+1
# Out:
# 2

# %%
'1'+'1'
# Out:
# '11'
